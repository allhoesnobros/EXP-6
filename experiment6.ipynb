# %% [markdown]
# <a href="https://colab.research.google.com/github/allhoesnobros/EXP-6/blob/main/experiment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aayush Vishwakarma
# 25070123125
# Study of conditional statement

# %%
a = int(input("Enter a number: "))
if (a>0):
 print("The given number is positive")
elif (a==0):
 print("The given number is zero")
else:
 print("The given number is negative")
# Out:
# Enter a number: 5
# The given number is positive

# %%
x = int(input("Enter a number: "))
if(x%2==0):
 print("The given number is even")
else:
 print("The given number is odd")
# Out:
# Enter a number: 4
# The given number is even

# %%
a = int(input("Enter the number a: "))
b = int(input("Enter the number b: "))
c = int(input("Enter the number c: "))
if(a>b and a>c):
 print("The greatest number is a")

elif(b>a and b>c):
 print("The greatest number is b")

else:
 print("The greatest number is c")
# Out:
# Enter the number a: 5
# Enter the number b: 1
# Enter the number c: 9
# The greatest number is c

# %%
marks = int(input("Enter the marks obtained in the subject: "))
if(marks>=90):
 print("The grade obtained is A")

elif(marks>=75 and marks<90):
  print("The grade obtained is B")

elif(marks>=60 and marks<75):
  print("The grade obtained is C")

elif(marks>=45 and marks<60):
  print("The grade obtained is D")

elif(marks<45):
  print("You have failed the subject")
# Out:
# Enter the marks obtained in the subject: 5
# You have failed the subject

# %%
year = int(input("Enter a year: "))

if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0):
    print("The entered year is a leap year")
else:
    print("The entered year is not a leap year")
# Out:
# Enter a year: 5555
# The entered year is not a leap year

# %%
print("Incremented Date if it is valid")

date = input("Enter the date in format (dd/mm/yyyy): ")
dd, mm, yy = map(int, date.split("/"))

# Find maximum days in the month
if mm == 1 or mm == 3 or mm == 5 or mm == 7 or mm == 8 or mm == 10 or mm == 12:
    max1 = 31

elif mm == 4 or mm == 6 or mm == 9 or mm == 11:
    max1 = 30

elif mm == 2:
    if (yy % 4 == 0 and yy % 100 != 0) or (yy % 400 == 0):
        max1 = 29
    else:
        max1 = 28

else:
    print("Date is invalid")
    exit()

# Validate date
if mm < 1 or mm > 12:
    print("Date is invalid")

elif dd < 1 or dd > max1:
    print("Date is invalid")

# Increment date
elif dd == max1 and mm != 12:
    dd = 1
    mm = mm + 1
    print("The incremented date is:", dd, mm, yy)

elif dd == 31 and mm == 12:
    dd = 1
    mm = 1
    yy = yy + 1
    print("The incremented date is:", dd, mm, yy)

else:
    dd = dd + 1
    print("The incremented date is:", dd, mm, yy)
# Out:
# Incremented Date if it is valid
# Enter the date in format (dd/mm/yyyy): 65/5/2007
# Date is invalid

# %%
alp = input("input an alphabet")

if alp in 'aeiouAEIOU':
  print("Vowel")

else:
  print("The input alphabet is a consonant")
# Out:
# input an alphabetg
# The input alphabet is a consonant

# %%
#write a python program to calculate the gross salary of an employee
'''if basic <=1: HRA = 20%, DA = 80%

if basic <=20000: HRA = 25%, DA = 90%

otherwise: HRA = 30%, DA = 95%

gross salary = basic + HRA + DA'''

basic = float(input("Enter the basic salary: "))

if basic <= 10000:
  hra = basic*0.20
  da = basic*0.80
elif basic <= 20000:
  hra = basic*0.25
  da = basic*0.90

else:
  hra = basic*0.30
  da = basic*0.95

gross_salary = basic + hra + da

print("Gross salary:", gross_salary)
# Out:
# Enter the basic salary: 20000
# Gross salary: 43000.0

# %%
income = float(input("Enter the annual income: "))
tax = 0 # Initialize tax to avoid NameError

if income <= 250000:
  tax = 0

elif income <= 500000:
  # Income is between 250,001 and 500,000
  tax = (income - 250000) * 0.05

elif income <= 1000000:
  # Income is between 500,001 and 1,000,000
  # Tax on first 250,000 (250k-500k slab)
  tax = (500000 - 250000) * 0.05
  # Tax on income above 500,000
  tax += (income - 500000) * 0.20

else:
  # Income is above 1,000,000
  # Tax on first 250,000 (250k-500k slab)
  tax = (500000 - 250000) * 0.05
  # Tax on next 500,000 (500k-1M slab)
  tax += (1000000 - 500000) * 0.20

  tax += (income - 1000000) * 0.30

print("Income Tax:", tax)
# Out:
# Enter the annual income: 2
# Income Tax: 0
